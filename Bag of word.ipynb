# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("C:\\Users\\Admin\\Desktop\\Data science\\spam.csv")
df.head()
# Out:
#   Category                                            Message
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...

# %%
df.Category.value_counts()
# Out:
# Category
# ham     4825
# spam     747
# Name: count, dtype: int64

# %%
df['spam'] = df['Category'].apply(lambda x: 1 if x =='spam' else 0)

# %%
df
# Out:
#      Category                                            Message  spam
# 0         ham  Go until jurong point, crazy.. Available only ...     0
# 1         ham                      Ok lar... Joking wif u oni...     0
# 2        spam  Free entry in 2 a wkly comp to win FA Cup fina...     1
# 3         ham  U dun say so early hor... U c already then say...     0
# 4         ham  Nah I don't think he goes to usf, he lives aro...     0
# ...       ...                                                ...   ...
# 5567     spam  This is the 2nd time we have tried 2 contact u...     1
# 5568      ham               Will ü b going to esplanade fr home?     0
# 5569      ham  Pity, * was in mood for that. So...any other s...     0
# 5570      ham  The guy did some bitching but I acted like i'd...     0
# 5571      ham                         Rofl. Its true to its name     0
#
# [5572 rows x 3 columns]

# %%
df.shape
# Out:
# (5572, 3)

# %%
df.head()
# Out:
#   Category                                            Message  spam
# 0      ham  Go until jurong point, crazy.. Available only ...     0
# 1      ham                      Ok lar... Joking wif u oni...     0
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...     1
# 3      ham  U dun say so early hor... U c already then say...     0
# 4      ham  Nah I don't think he goes to usf, he lives aro...     0

# %% [raw]
# Train test split

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(df.Message, df.spam, test_size=0.2)

# %%
X_train.shape
# Out:
# (4457,)

# %%
X_test.shape
# Out:
# (1115,)

# %%
type(X_train)
# Out:
# pandas.core.series.Series

# %%
X_train[:14]
# Out:
# 3403    An Amazing Quote'' - "Sometimes in life its di...
# 5414                                           East coast
# 3172               Still otside le..u come 2morrow maga..
# 2471    Eat at old airport road... But now 630 oredi.....
# 2800    I've told him that i've returned it. That shou...
# 2907    Helloooo... Wake up..! "Sweet" "morning" "welc...
# 1004        &lt;#&gt;  am I think? Should say on syllabus
# 3422    Welcome! Please reply with your AGE and GENDER...
# 696                  Good. Good job. I like entrepreneurs
# 2538            That's y we haf to combine n c how lor...
# 441     Yes..he is really great..bhaji told kallis bes...
# 3947    How u doin baby girl ?? hope u are okay every ...
# 4730                                I've reached already.
# 3440    awesome, how do I deal with the gate? Charles ...
# Name: Message, dtype: object

# %%
X_train[0:14]
# Out:
# 3403    An Amazing Quote'' - "Sometimes in life its di...
# 5414                                           East coast
# 3172               Still otside le..u come 2morrow maga..
# 2471    Eat at old airport road... But now 630 oredi.....
# 2800    I've told him that i've returned it. That shou...
# 2907    Helloooo... Wake up..! "Sweet" "morning" "welc...
# 1004        &lt;#&gt;  am I think? Should say on syllabus
# 3422    Welcome! Please reply with your AGE and GENDER...
# 696                  Good. Good job. I like entrepreneurs
# 2538            That's y we haf to combine n c how lor...
# 441     Yes..he is really great..bhaji told kallis bes...
# 3947    How u doin baby girl ?? hope u are okay every ...
# 4730                                I've reached already.
# 3440    awesome, how do I deal with the gate? Charles ...
# Name: Message, dtype: object

# %%
type(y_train)
# Out:
# pandas.core.series.Series

# %%
y_train[:4]
# Out:
# 3403    0
# 5414    0
# 3172    0
# 2471    0
# Name: spam, dtype: int64

# %%
type(X_train.values)
# Out:
# numpy.ndarray

# %% [markdown]
# Create bag of words representation using CountVectorizer

# %%
from sklearn.feature_extraction.text import CountVectorizer

v = CountVectorizer()

X_train_cv = v.fit_transform(X_train.values)
X_train_cv
# Out:
# <4457x7772 sparse matrix of type '<class 'numpy.int64'>'
# 	with 59081 stored elements in Compressed Sparse Row format>

# %%
X_train_cv.toarray()[:2][0]
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
X_train_cv.shape
# Out:
# (4457, 7772)

# %%
v.get_feature_names_out()[1771]
# Out:
# 'chatlines'

# %%
v.get_feature_names_out()[171]
# Out:
# '09057039994'

# %%
v.vocabulary_
# Out:
# {'an': 969,
#  'amazing': 949,
#  'quote': 5570,
#  'sometimes': 6342,
#  'in': 3666,
#  'life': 4122,
#  'its': 3793,
#  'difficult': 2341,
#  'to': 6963,
#  'decide': 2226,
#  'whats': 7503,
#  'wrong': 7656,
#  'lie': 4120,
#  'that': 6840,
#  'brings': 1534,
#  'smile': 6285,
#  'or': 4997,
#  'the': 6844,
#  'truth': 7086,
#  'tear': 6772,
#  'east': 2532,
#  'coast': 1892,
#  'still': 6514,
#  'otside': 5028,
#  'le': 4072,
#  'come': 1927,
#  '2morrow': 412,
#  'maga': 4329,
#  'eat': 2536,
#  'at': 1131,
#  'old': 4951,
#  'airport': 897,
#  'road': 5832,
#  'but': 1601,
#  'now': 4864,
#  '630': 597,
#  'oredi': 5009,
#  'got': 3217,
#  'lot': 4233,
#  'of': 4913,
#  'pple': 5379,
#  've': 7289,
#  'told': 6980,
#  'him': 3462,
#  'returned': 5794,
#  'it': 3785,
#  'should': 6154,
#  're': 5622,
#  'order': 5005,
#  'helloooo': 3423,
#  'wake': 7388,
#  'up': 7214,
#  'sweet': 6682,
#  'morning': 4606,
#  'welcomes': 7483,
#  'you': 7733,
#  'enjoy': 2623,
#  'this': 6880,
#  'day': 2206,
#  'with': 7577,
#  'full': 3058,
#  'joy': 3878,
#  'gud': 3282,
#  'mrng': 4631,
#  'lt': 4269,
#  'gt': 3276,
#  'am': 948,
#  'think': 6872,
#  'say': 5959,
#  'on': 4957,
#  'syllabus': 6698,
#  'welcome': 7482,
#  'please': 5278,
#  'reply': 5749,
#  'your': 7739,
#  'age': 875,
#  'and': 974,
#  'gender': 3119,
#  'begin': 1325,
#  '24m': 376,
#  'good': 3203,
#  'job': 3857,
#  'like': 4133,
#  'entrepreneurs': 2640,
#  'we': 7447,
#  'haf': 3313,
#  'combine': 1926,
#  'how': 3547,
#  'lor': 4225,
#  'yes': 7716,
#  'he': 3388,
#  'is': 3775,
#  'really': 5642,
#  'great': 3253,
#  'bhaji': 1362,
#  'kallis': 3912,
#  'best': 1348,
#  'cricketer': 2099,
#  'after': 867,
#  'sachin': 5905,
#  'world': 7627,
#  'very': 7303,
#  'tough': 7027,
#  'get': 3134,
#  'out': 5032,
#  'doin': 2418,
#  'baby': 1208,
#  'girl': 3155,
#  'hope': 3516,
#  'are': 1063,
#  'okay': 4940,
#  'every': 2689,
#  'time': 6931,
#  'call': 1634,
#  'ure': 7234,
#  'phone': 5215,
#  'off': 4915,
#  'miss': 4525,
#  'touch': 7025,
#  'reached': 5624,
#  'already': 939,
#  'awesome': 1189,
#  'do': 2397,
#  'deal': 2213,
#  'gate': 3102,
#  'charles': 1762,
#  'me': 4424,
#  'last': 4043,
#  'night': 4799,
#  'uh': 7147,
#  'yeah': 7706,
#  'reach': 5623,
#  'home': 3502,
#  'safe': 5911,
#  'sound': 6373,
#  'liao': 4113,
#  'ultimately': 7154,
#  'tor': 7015,
#  'motive': 4615,
#  'tui': 7100,
#  'achieve': 804,
#  'korli': 3992,
#  '1000': 263,
#  'flirting': 2919,
#  'txt': 7125,
#  'bloke': 1413,
#  'ur': 7232,
#  'name': 4706,
#  'eg': 2564,
#  'zoe': 7765,
#  '18': 327,
#  '8007': 652,
#  'join': 3863,
#  'chatting': 1773,
#  'babe': 1205,
#  'answering': 997,
#  'can': 1656,
#  'see': 6016,
#  'maybe': 4418,
#  'better': 1353,
#  'reboot': 5652,
#  'ym': 7726,
#  'photo': 5220,
#  'dont': 2432,
#  'show': 6160,
#  'yourself': 7744,
#  'far': 2798,
#  'put': 5539,
#  'new': 4781,
#  'pictures': 5235,
#  'facebook': 2767,
#  '2nd': 415,
#  'have': 3378,
#  'tried': 7066,
#  'contact': 2000,
#  'won': 7604,
#  '750': 634,
#  'pound': 5370,
#  'prize': 5450,
#  'claim': 1844,
#  'easy': 2535,
#  '08718726970': 140,
#  'only': 4969,
#  '10p': 273,
#  'per': 5175,
#  'min': 4501,
#  'bt': 1565,
#  'national': 4725,
#  'rate': 5608,
#  'want': 7408,
#  'lick': 4117,
#  'pussy': 5538,
#  'protect': 5497,
#  'from': 3040,
#  'threats': 6896,
#  'sib': 6181,
#  'never': 4777,
#  'asks': 1111,
#  'for': 2960,
#  'sensitive': 6052,
#  'information': 3701,
#  'passwords': 5133,
#  'atm': 1137,
#  'sms': 6296,
#  'pin': 5245,
#  'thru': 6907,
#  'email': 2592,
#  'share': 6101,
#  'password': 5132,
#  'anybody': 1006,
#  'shb': 6106,
#  'ok': 4939,
#  'thanx': 6839,
#  'sad': 5908,
#  'story': 6536,
#  'man': 4355,
#  'week': 7468,
#  'was': 7421,
#  'my': 4686,
#  'wife': 7538,
#  'did': 2328,
#  'nt': 4869,
#  'wish': 7569,
#  'parents': 5111,
#  'forgot': 2973,
#  'so': 6316,
#  'kids': 3954,
#  'went': 7488,
#  'work': 7620,
#  'even': 2683,
#  'colleagues': 1912,
#  'not': 4850,
#  'as': 1101,
#  'entered': 2633,
#  'cabin': 1622,
#  'pa': 5070,
#  'said': 5915,
#  'happy': 3354,
#  'boss': 1459,
#  'felt': 2836,
#  'special': 6398,
#  'she': 6108,
#  'askd': 1107,
#  'lunch': 4282,
#  'invited': 3754,
#  'her': 3436,
#  'apartment': 1020,
#  'there': 6860,
#  'mind': 4503,
#  'if': 3625,
#  'go': 3179,
#  'into': 3746,
#  'bedroom': 1313,
#  'minute': 4516,
#  'sed': 6015,
#  'sexy': 6080,
#  'mood': 4599,
#  'came': 1652,
#  'minuts': 4518,
#  'latr': 4051,
#  'wid': 7535,
#  'cake': 1626,
#  'kidz': 3955,
#  'friends': 3026,
#  'all': 926,
#  'screaming': 5991,
#  'surprise': 6661,
#  'waiting': 7387,
#  'sofa': 6319,
#  'naked': 4703,
#  'started': 6480,
#  'searching': 6002,
#  'will': 7546,
#  'few': 2842,
#  'days': 2207,
#  'potential': 5367,
#  'talent': 6728,
#  'indians': 3690,
#  'poor': 5337,
#  'india': 3688,
#  'country': 2057,
#  'says': 5963,
#  'one': 4963,
#  'swiss': 6691,
#  'bank': 1240,
#  'directors': 2361,
#  'lac': 4012,
#  'crore': 2103,
#  'indian': 3689,
#  'money': 4588,
#  'deposited': 2280,
#  'banks': 1241,
#  'which': 7517,
#  'be': 1292,
#  'used': 7249,
#  'taxless': 6757,
#  'budget': 1572,
#  'yrs': 7749,
#  'give': 3161,
#  'jobs': 3858,
#  'any': 1005,
#  'village': 7325,
#  'delhi': 2258,
#  'lane': 4029,
#  'roads': 5833,
#  'forever': 2965,
#  'free': 3005,
#  'power': 5376,
#  'suply': 6642,
#  'more': 4602,
#  'than': 6831,
#  'social': 6318,
#  'projects': 5475,
#  'citizen': 1840,
#  'monthly': 4596,
#  'no': 4818,
#  'need': 4750,
#  'amp': 963,
#  'imf': 3644,
#  'loan': 4189,
#  'our': 5029,
#  'blocked': 1412,
#  'by': 1617,
#  'rich': 5810,
#  'politicians': 5321,
#  'rights': 5816,
#  'against': 873,
#  'corrupt': 2039,
#  'itna': 3791,
#  'forward': 2986,
#  'karo': 3922,
#  'ki': 3946,
#  'pura': 5528,
#  'padhe': 5076,
#  'private': 5448,
#  '2003': 358,
#  'account': 801,
#  'statement': 6485,
#  'shows': 6168,
#  '800': 649,
#  'un': 7161,
#  'redeemed': 5682,
#  'points': 5315,
#  '08718738001': 147,
#  'identifier': 3619,
#  'code': 1900,
#  '49557': 519,
#  'expires': 2743,
#  '26': 382,
#  '11': 276,
#  '04': 14,
#  'spoil': 6434,
#  'bed': 1309,
#  'well': 7484,
#  'bring': 1532,
#  'tat': 6749,
#  'cd': 1722,
#  'don': 2429,
#  'forget': 2968,
#  'bad': 1216,
#  'lady': 4016,
#  'anything': 1012,
#  'tick': 6917,
#  'where': 7511,
#  'could': 2051,
#  'die': 2332,
#  'loneliness': 4209,
#  'know': 3980,
#  'pouts': 5375,
#  'stomps': 6522,
#  'feet': 2833,
#  'noe': 4822,
#  'wat': 7428,
#  'place': 5257,
#  'dat': 2196,
#  'sells': 6037,
#  '4d': 522,
#  'closes': 1873,
#  'waliking': 7391,
#  'ard': 1062,
#  'wan': 7403,
#  'buy': 1605,
#  'house': 3543,
#  'dunno': 2512,
#  'jus': 3895,
#  'lido': 4119,
#  'same': 5927,
#  '930': 740,
#  'actual': 820,
#  'exam': 2715,
#  'harder': 3357,
#  'nbme': 4735,
#  'when': 7507,
#  'wanna': 7406,
#  'gym': 3303,
#  'harri': 3363,
#  'then': 6855,
#  'todays': 6970,
#  'plan': 5261,
#  'convey': 2016,
#  'regards': 5699,
#  'pls': 5285,
#  'prometazine': 5477,
#  'syrup': 6704,
#  '5mls': 578,
#  'mins': 4513,
#  'later': 4048,
#  'feed': 2825,
#  'much': 4652,
#  'cleaning': 1857,
#  'result': 5786,
#  '1st': 344,
#  'ringtone': 5822,
#  'msg': 4634,
#  'tone': 6992,
#  'gr8': 3230,
#  'top': 7010,
#  '20': 355,
#  'tones': 6993,
#  'just': 3896,
#  '50': 548,
#  'wk': 7585,
#  'opt': 4992,
#  'send': 6043,
#  'stop': 6527,
#  '08452810071': 65,
#  '16': 322,
#  'll': 4181,
#  'take': 6722,
#  'care': 1680,
#  'gettin': 3140,
#  'rdy': 5621,
#  'ship': 6125,
#  'comp': 1940,
#  'boy': 1489,
#  'words': 7619,
#  'left': 4087,
#  'sighs': 6187,
#  'goes': 3187,
#  'love': 4246,
#  'start': 6479,
#  'studying': 6569,
#  'finally': 2869,
#  'has': 3365,
#  'happened': 3346,
#  'aftr': 870,
#  'decades': 2224,
#  'beer': 1317,
#  'cheaper': 1775,
#  'petrol': 5202,
#  'goverment': 3225,
#  'expects': 2738,
#  'us': 7244,
#  'drink': 2472,
#  'drive': 2477,
#  'network': 4772,
#  'urgnt': 7238,
#  'message': 4475,
#  'some': 6330,
#  'text': 6818,
#  'missing': 4528,
#  'sender': 6044,
#  'number': 4877,
#  'sent': 6053,
#  'date': 2198,
#  'thats': 6843,
#  'everything': 2697,
#  'via': 7306,
#  'fullonsms': 3059,
#  'com': 1922,
#  'tell': 6788,
#  'shit': 6130,
#  'dirty': 2363,
#  'fellow': 2835,
#  'nope': 4838,
#  'sch': 5972,
#  'daddy': 2173,
#  'em': 2591,
#  'someplace': 6336,
#  'probably': 5455,
#  'while': 7518,
#  'edison': 2549,
#  'rightly': 5815,
#  'fool': 2953,
#  'ask': 1106,
#  'questions': 5559,
#  'wise': 7568,
#  'answer': 996,
#  'why': 7531,
#  'speechless': 6406,
#  'during': 2515,
#  'viva': 7342,
#  'gm': 3173,
#  'gn': 3175,
#  'ge': 3113,
#  'gnt': 3177,
#  'oh': 4934,
#  'wait': 7384,
#  'lect': 4084,
#  'havent': 3381,
#  'finish': 2877,
#  'wasn': 7423,
#  'available': 1171,
#  'washob': 7422,
#  'nobbing': 4820,
#  'they': 6865,
#  'had': 3311,
#  'nickey': 4795,
#  'platt': 5268,
#  'instead': 3728,
#  'hey': 3447,
#  'what': 7501,
#  'driving': 2480,
#  'fri': 3020,
#  'evaluation': 2679,
#  'chance': 1747,
#  'reality': 5638,
#  'fantasy': 2797,
#  '08707509020': 85,
#  '20p': 364,
#  'ntt': 4872,
#  'ltd': 4270,
#  'po': 5294,
#  'box': 1472,
#  '1327': 298,
#  'croydon': 2106,
#  'cr9': 2075,
#  '5wb': 582,
#  '0870': 68,
#  'thanks': 6834,
#  'appreciate': 1044,
#  'sacrifice': 5907,
#  'sure': 6654,
#  'process': 5463,
#  'direct': 2358,
#  'pay': 5145,
#  'find': 2871,
#  'way': 7443,
#  'back': 1213,
#  'test': 6813,
#  'tomorrow': 6990,
#  'class': 1852,
#  'wonderful': 7607,
#  'im': 3638,
#  'arestaurant': 1067,
#  'eating': 2539,
#  'squid': 6458,
#  'about': 773,
#  '10': 261,
#  '30': 434,
#  'dosomething': 2445,
#  'late': 4045,
#  'make': 4345,
#  'squeezed': 6457,
#  'bucks': 1568,
#  'dad': 2172,
#  'until': 7212,
#  '545': 572,
#  'ya': 7694,
#  'dinner': 2354,
#  'together': 6973,
#  'maggi': 4331,
#  'mee': 4440,
#  'depends': 2278,
#  'individual': 3692,
#  'hair': 3317,
#  'dresser': 2471,
#  'pretty': 5429,
#  'look': 4214,
#  'gong': 3200,
#  'kaypoh': 3927,
#  'also': 942,
#  'collecting': 1915,
#  'prabha': 5383,
#  'soryda': 6370,
#  'realy': 5644,
#  'frm': 3031,
#  'heart': 3403,
#  'sory': 6369,
#  'yup': 7756,
#  'beautiful': 1299,
#  'comes': 1929,
#  'today': 6969,
#  'hunt': 3579,
#  'waste': 7425,
#  'goodmorning': 3205,
#  'change': 1749,
#  'fb': 2817,
#  'jaykwon': 3827,
#  'thuglyfe': 6911,
#  'falconerf': 2782,
#  'shitload': 6133,
#  'diamonds': 2322,
#  'though': 6890,
#  'freemsg': 3011,
#  'ready': 5632,
#  'horny': 3527,
#  'live': 4174,
#  'town': 7031,
#  'sex': 6076,
#  'fun': 3061,
#  'games': 3088,
#  'netcollex': 4769,
#  '08700621170150p': 71,
#  'end': 2608,
#  'long': 4211,
#  'remember': 5721,
#  'cos': 2040,
#  'didn': 2329,
#  'nighters': 4800,
#  'persevered': 5188,
#  'found': 2989,
#  'cheap': 1774,
#  'apologise': 1027,
#  'advance': 847,
#  'somewhere': 6344,
#  'sleep': 6252,
#  'isnt': 3781,
#  'may': 4416,
#  'win': 7549,
#  'winner': 7560,
#  'mr': 4630,
#  'foley': 2940,
#  'ipod': 3766,
#  'exciting': 2720,
#  'prizes': 5452,
#  'soon': 6354,
#  'keep': 3930,
#  'eye': 2759,
#  'mobile': 4560,
#  'visit': 7338,
#  'www': 7669,
#  '82050': 668,
#  'co': 1890,
#  'uk': 7151,
#  'symptoms': 6701,
#  'listening': 4166,
#  'songs': 6350,
#  'stopped': 6530,
#  'beloved': 1339,
#  'angry': 981,
#  'were': 7491,
#  'gonna': 3201,
#  'tacos': 6712,
#  'again': 872,
#  'company': 1943,
#  'environment': 2647,
#  'terrific': 6809,
#  'food': 2952,
#  'nice': 4792,
#  'makes': 4346,
#  'people': 5173,
#  'dearer': 2219,
#  'de': 2211,
#  'happiness': 3353,
#  'feel': 2826,
#  'meet': 4441,
#  'them': 6852,
#  'pain': 5081,
#  'dem': 2264,
#  'must': 4678,
#  'sit': 6222,
#  'around': 1085,
#  'summer': 6624,
#  'celebrate': 1728,
#  'such': 6601,
#  'magical': 4333,
#  'sight': 6188,
#  'worlds': 7628,
#  'dressed': 2470,
#  'white': 7521,
#  'oooooh': 4978,
#  'let': 4106,
#  'snow': 6312,
#  'printer': 5443,
#  'cool': 2025,
#  'mean': 4427,
#  'groovy': 3265,
#  'wine': 7556,
#  'groovying': 3266,
#  'comprehensive': 1958,
#  'mail': 4339,
#  'who': 7523,
#  'paying': 5151,
#  'going': 3192,
#  'seventeen': 6074,
#  'pounds': 5372,
#  'seven': 6073,
#  'hundred': 3573,
#  'ml': 4546,
#  'finished': 2879,
#  'meeting': 4443,
#  'da': 2168,
#  'nite': 4812,
#  'tmr': 6957,
#  'soooo': 6358,
#  'hear': 3400,
#  'omg': 4955,
#  'missed': 4526,
#  'sorry': 6363,
#  'having': 3383,
#  'problems': 5458,
#  'provider': 5501,
#  'thank': 6833,
#  'tming': 6955,
#  'boooo': 1449,
#  'always': 946,
#  'quit': 5563,
#  'cant': 1667,
#  'taste': 6747,
#  'real': 5633,
#  'thing': 6870,
#  'dear': 2217,
#  'believe': 1331,
#  'attached': 1140,
#  'seeing': 6018,
#  'teach': 6766,
#  'midnight': 4489,
#  'haven': 3380,
#  'forgotten': 2974,
#  'might': 4491,
#  'couple': 2060,
#  'too': 7002,
#  'offer': 4920,
#  '150': 310,
#  'textand': 6820,
#  'video': 7313,
#  '08002988890': 54,
#  'delivery': 2262,
#  'hi': 3451,
#  'dis': 2364,
#  'yijue': 7725,
#  'would': 7641,
#  'wif': 7537,
#  'gek1510': 3118,
#  'display': 2379,
#  'internal': 3740,
#  'subs': 6586,
#  'gotta': 3222,
#  'extract': 2756,
#  'include': 3673,
#  'mcfly': 4422,
#  'ab': 761,
#  'sara': 5936,
#  'jorge': 3875,
#  'shock': 6137,
#  'smith': 6289,
#  'switch': 6692,
#  'follow': 2942,
#  'instructions': 3730,
#  'next': 4789,
#  'dude': 2503,
#  'longer': 4212,
#  'pisces': 5248,
#  'aquarius': 1058,
#  'theory': 6857,
#  'argument': 1073,
#  'wins': 7562,
#  'situation': 6228,
#  'loses': 4229,
#  'person': 5190,
#  'argue': 1071,
#  'kick': 3948,
#  'correct': 2036,
#  'university': 7195,
#  'southern': 6380,
#  'california': 1633,
#  'jokin': 3868,
#  'oni': 4965,
#  'lar': 4037,
#  'busy': 1600,
#  'wun': 7668,
#  'disturb': 2382,
#  'weird': 7477,
#  'bein': 1329,
#  'woah': 7598,
#  'realising': 5637,
#  'actually': 821,
#  'reasonable': 5648,
#  'meant': 4431,
#  'calculation': 1630,
#  'units': 7193,
#  'school': 5974,
#  'expensive': 2739,
#  'practicing': 5387,
#  'accent': 788,
#  'because': 1303,
#  'important': 3654,
#  'decided': 2227,
#  'doing': 2419,
#  '4years': 547,
#  'dental': 2271,
#  'nmde': 4817,
#  'been': 1315,
#  'before': 1321,
#  'yoga': 7729,
#  'book': 1443,
#  'kindly': 3964,
#  'flat': 2907,
#  'decimal': 2229,
#  'small': 6276,
#  'dose': 2444,
#  'tablet': 6710,
#  'fever': 2841,
#  'watching': 7432,
#  'entertaining': 2635,
#  'getting': 3141,
#  'whole': 7525,
#  'hugh': 3565,
#  'laurie': 4057,
#  'stick': 6510,
#  'indeed': 3685,
#  'especially': 2667,
#  'consensus': 1993,
#  'little': 4173,
#  'surprised': 6662,
#  'spent': 6416,
#  'evening': 2684,
#  'french': 3015,
#  'guy': 3299,
#  'met': 4481,
#  'here': 3437,
#  'fooled': 2954,
#  'bit': 1387,
#  'fuck': 3049,
#  'reminder': 5727,
#  'downloaded': 2454,
#  'content': 2004,
#  'paid': 5080,
#  'goto': 3221,
#  'http': 3557,
#  'doit': 2420,
#  'mymoby': 4689,
#  'tv': 7113,
#  'collect': 1913,
#  'cuz': 2162,
#  'ibored': 3605,
#  'study': 6568,
#  'hate': 3370,
#  'didnt': 2330,
#  'accept': 789,
#  'single': 6211,
#  'mine': 4505,
#  'messaged': 4476,
#  'club': 1877,
#  'expired': 2742,
#  'sub': 6582,
#  'monoc': 4592,
#  'monos': 4593,
#  'polyc': 5325,
#  'polys': 5329,
#  'weekly': 7472,
#  '150p': 312,
#  'stream': 6541,
#  '0871212025016': 95,
#  'deepest': 2241,
#  'darkest': 2190,
#  'fantasies': 2795,
#  '09094646631': 248,
#  '60p': 589,
#  'texts': 6829,
#  '08712460324': 108,
#  'nat': 4720,
#  'railway': 5582,
#  'buns': 1586,
#  'word': 7618,
#  '44': 499,
#  '7732584351': 638,
#  'nokia': 4826,
#  '3510i': 457,
#  'colour': 1920,
#  'deliveredtomorrow': 2261,
#  '300': 435,
#  'minutes': 4517,
#  '100': 262,
#  'camcorder': 1651,
#  '08000930705': 48,
#  'lets': 4107,
#  'use': 7248,
#  'princess': 5440,
#  'auntie': 1160,
#  'huai': 3559,
#  'juan': 3884,
#  'pick': 5228,
#  'dislikes': 2378,
#  'laptop': 4036,
#  'matric': 4404,
#  'card': 1677,
#  'lei': 4093,
#  'afternoon': 869,
#  'starshine': 6478,
#  'boytoy': 1494,
#  'does': 2408,
#  'crave': 2082,
#  'yet': 7719,
#  'ache': 803,
#  'sips': 6216,
#  'cappuccino': 1672,
#  'teasing': 6775,
#  'kiss': 3969,
#  'wot': 7638,
#  'bitch': 1388,
#  'brought': 1551,
#  'gmw': 3174,
#  'connected': 1989,
#  'completed': 1953,
#  'degree': 2250,
#  'joining': 3865,
#  'finance': 2870,
#  'clearly': 1861,
#  'fault': 2810,
#  'merry': 4472,
#  'christmas': 1833,
#  'annie': 986,
#  'nothing': 4855,
#  'wen': 7486,
#  'something': 6340,
#  'value': 7276,
#  'wil': 7543,
#  'realized': 5640,
#  'their': 6849,
#  'absence': 776,
#  'right': 5814,
#  'hillsborough': 3461,
#  'th': 6830,
#  'alright': 940,
#  'god': 3185,
#  'limit': 4142,
#  'grace': 3233,
#  'measure': 4433,
#  'boundaries': 1467,
#  'endless': 2611,
#  'blessings': 1408,
#  'ni8': 4790,
#  'once': 4961,
#  'sir': 6217,
#  'making': 4349,
#  'babies': 1207,
#  'rd': 5620,
#  'challenge': 1742,
#  'shuhui': 6175,
#  'suntec': 6636,
#  'steamboat': 6500,
#  '7250i': 630,
#  'auction': 1154,
#  'part': 5118,
#  '86021': 696,
#  'hg': 3449,
#  'suite342': 6616,
#  '2lands': 407,
#  'row': 5862,
#  'w1jhl': 7370,
#  'working': 7624,
#  'taj': 6720,
#  'mahal': 4335,
#  'symbol': 6699,
#  'other': 5023,
#  'lesser': 4103,
#  'known': 3982,
#  'facts': 2770,
#  'mumtaz': 4667,
#  'shahjahan': 6090,
#  '4th': 537,
#  'his': 3469,
#  'wifes': 7539,
#  'killed': 3958,
#  'husband': 3587,
#  'marry': 4384,
#  'died': 2333,
#  'married': 4383,
#  'sister': 6220,
#  'question': 5557,
#  'arises': 1077,
#  'hell': 3419,
#  'hari': 3360,
#  'explicit': 2746,
#  'secs': 6013,
#  'ring': 5819,
#  '02073162414': 10,
#  'costs': 2045,
#  'shijutta': 6122,
#  'successful': 6599,
#  'maid': 4338,
#  'murderer': 4673,
#  'coz': 2070,
#  'murdered': 4672,
#  'january': 3819,
#  'public': 5516,
#  'holiday': 3498,
#  'govt': 3226,
#  'instituitions': 3729,
#  'closed': 1871,
#  'including': 3675,
#  'post': 5358,
#  'office': 4924,
#  'understand': 7176,
#  'ree': 5684,
#  'entry': 2642,
#  'pod': 5311,
#  '80182': 658,
#  ...}

# %%
X_train_np = X_train_cv.toarray()
X_train_np[0]
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
np.where(X_train_np[0]!=0)
# Out:
# (array([ 949,  969, 1534, 2226, 2341, 3666, 3793, 4120, 4122, 4997, 5570,
#         6285, 6342, 6772, 6840, 6844, 6963, 7086, 7503, 7656], dtype=int64),)

# %%
X_train_np[0][1771]
# Out:
# 0

# %% [raw]
# Train the naive bayes model

# %%
from sklearn.naive_bayes import MultinomialNB

model = MultinomialNB()
model.fit(X_train_cv, y_train)
# Out:
# MultinomialNB()

# %%
X_test_cv = v.transform(X_test)

# %% [markdown]
# Evaluate Performance

# %%
from sklearn.metrics import classification_report

y_pred = model.predict(X_test_cv)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       962
#            1       0.96      0.93      0.95       153
#
#     accuracy                           0.99      1115
#    macro avg       0.97      0.96      0.97      1115
# weighted avg       0.99      0.99      0.99      1115

# %%
emails = [
    'Hey mohan, can we get together to watch footbal game tomorrow?',
    'Upto 20% discount on parking, exclusive offer just for you. Dont miss this reward!'
]

emails_count = v.transform(emails)
model.predict(emails_count)
# Out:
# array([0, 1], dtype=int64)

# %% [markdown]
# Train the model using sklearn pipeline and reduce number of lines of code

# %%
from sklearn.pipeline import Pipeline

clf = Pipeline([
    ('vectorizer', CountVectorizer()),
    ('nb', MultinomialNB())
])

# %%
clf.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('vectorizer', CountVectorizer()), ('nb', MultinomialNB())])

# %%
y_pred = clf.predict(X_test)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       962
#            1       0.96      0.93      0.95       153
#
#     accuracy                           0.99      1115
#    macro avg       0.97      0.96      0.97      1115
# weighted avg       0.99      0.99      0.99      1115
